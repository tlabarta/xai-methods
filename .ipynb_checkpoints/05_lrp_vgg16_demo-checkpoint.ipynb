# %%
# %% Imports
import torch
import torch.nn as nn
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
import torch.optim as optim
import copy
import pandas as pd

# %%
# Set GPU device
print(torch.cuda.is_available())
device = torch.device("mps")


# %% Load data
TRAIN_ROOT = "data/brain_mri/training"
TEST_ROOT = "data/brain_mri/testing"
train_dataset = torchvision.datasets.ImageFolder(root=TRAIN_ROOT)
test_dataset = torchvision.datasets.ImageFolder(root=TRAIN_ROOT)
# Out:
# False

# %%
# %% Building the model
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.vgg16 = models.vgg16(weights=True)

        # Replace output layer according to our problem
        in_feats = self.vgg16.classifier[6].in_features
        self.vgg16.classifier[6] = nn.Linear(in_feats, 4)

    def forward(self, x):
        x = self.vgg16(x)
        return x

model = CNNModel()
model.to(device)
model
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ip4rs/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# CNNModel(
#   (vgg16): VGG(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (6): ReLU(inplace=True)
#       (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): ReLU(inplace=True)
#       (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): ReLU(inplace=True)
#       (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): ReLU(inplace=True)
#       (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (15): ReLU(inplace=True)
#       (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (18): ReLU(inplace=True)
#       (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (20): ReLU(inplace=True)
#       (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (22): ReLU(inplace=True)
#       (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (25): ReLU(inplace=True)
#       (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (27): ReLU(inplace=True)
#       (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (29): ReLU(inplace=True)
#       (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#     (classifier): Sequential(
#       (0): Linear(in_features=25088, out_features=4096, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.5, inplace=False)
#       (3): Linear(in_features=4096, out_features=4096, bias=True)
#       (4): ReLU(inplace=True)
#       (5): Dropout(p=0.5, inplace=False)
#       (6): Linear(in_features=4096, out_features=4, bias=True)
#     )
#   )
# )

# %%
# %% Prepare data for pretrained model
train_dataset = torchvision.datasets.ImageFolder(
        root=TRAIN_ROOT,
        transform=transforms.Compose([
                      transforms.Resize((255,255)),
                      transforms.ToTensor()
        ])
)

test_dataset = torchvision.datasets.ImageFolder(
        root=TEST_ROOT,
        transform=transforms.Compose([
                      transforms.Resize((255,255)),
                      transforms.ToTensor()
        ])
)

# %%
# %% Create data loaders
batch_size = 32
train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True
)
test_loader = torch.utils.data.DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=True
)

# %%
# %% Train
cross_entropy_loss = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.00001)
epochs = 10

# Iterate x epochs over the train data
for epoch in range(epochs):
    for i, batch in enumerate(train_loader, 0):
        inputs, labels = batch
        inputs = inputs.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        # Labels are automatically one-hot-encoded
        loss = cross_entropy_loss(outputs, labels)
        loss.backward()
        optimizer.step()
        print(loss)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ip4rs/lib/python3.9/site-packages/torch/_tensor_str.py:115: UserWarning: The operator 'aten::nonzero' is not currently supported on the MPS backend and will fall back to run on the CPU. This may have performance implications. (Triggered internally at /Users/runner/work/_temp/anaconda/conda-bld/pytorch_1670525849783/work/aten/src/ATen/mps/MPSFallback.mm:11.)
#   nonzero_finite_vals = torch.masked_select(
# tensor(1.3803, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.3702, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.5514, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.3418, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.2982, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.3281, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.3232, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.2952, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.3005, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.3619, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.3008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.2352, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.1262, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.1534, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.3038, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.1140, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.1901, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.2553, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.2222, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.1199, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.1622, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.1144, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.0346, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.1197, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.0389, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.0477, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.0160, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.0555, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.9684, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.0599, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.9436, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.8531, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.1855, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.9528, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.0146, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.7463, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.7136, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.8440, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.0690, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.2367, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.9291, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.8344, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.7811, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.7916, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.8827, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.7531, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.7879, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.6375, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.6637, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.8871, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.6156, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5445, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.6237, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.7546, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5817, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.6539, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.7776, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5097, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4677, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5924, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4911, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4778, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.6052, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.6202, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.6922, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.6323, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.7026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5470, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.6061, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5142, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.6404, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4919, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.6992, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.7497, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5881, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5868, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3448, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.6899, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4604, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5509, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4033, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.7132, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5497, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3739, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5263, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5345, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5104, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4869, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.8379, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5732, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4682, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4086, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4432, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4568, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5282, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4562, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5298, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4743, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4161, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4066, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3632, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3881, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5644, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5687, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3762, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3132, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2787, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2198, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3872, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4376, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3623, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2365, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3215, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4772, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3479, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5343, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4731, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3982, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3071, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2949, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5998, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3302, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.6598, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3804, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3105, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4289, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5512, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3231, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2221, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3028, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4248, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2265, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3686, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.6905, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3593, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4200, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5184, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1992, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2941, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4104, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4353, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3657, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3346, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3898, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4546, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3051, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4818, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2467, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4799, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2693, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2609, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2797, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2733, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4600, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3400, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3519, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1813, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2593, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1716, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2363, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2909, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4357, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2432, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3132, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3600, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2379, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2939, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4810, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1536, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3634, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3006, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3445, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3434, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4054, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1353, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2862, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2643, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4705, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3066, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2835, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1720, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3849, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2566, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2654, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2758, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1815, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2739, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2863, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1630, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1412, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1637, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3668, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1393, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1639, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0909, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1557, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1578, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4342, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2385, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1813, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1186, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3130, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2264, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0763, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3197, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2119, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1723, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0921, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1867, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3339, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1945, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4533, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2464, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1002, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2741, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3132, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4490, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2202, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1034, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2355, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1556, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.5153, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2740, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1391, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1831, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2318, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1351, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2620, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1838, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2522, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4180, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1155, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3693, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2740, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1692, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1171, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1762, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1603, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2182, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3609, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1232, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1049, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2247, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1339, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1209, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1421, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1511, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1177, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1591, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1619, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0863, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1410, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1028, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2588, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1694, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1941, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2501, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0648, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2914, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3555, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2828, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2507, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2803, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4294, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1959, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2583, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1055, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1522, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3305, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1068, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0947, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1117, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1888, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3112, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2260, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1615, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1341, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2897, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1291, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1534, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1569, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0957, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1082, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2724, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2540, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1364, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2960, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1786, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1195, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0679, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0546, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2297, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0608, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1306, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0455, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0631, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2165, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1119, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3102, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2048, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1430, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1401, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0271, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2474, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1679, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1915, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0618, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2831, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2090, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1162, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1629, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0425, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0890, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0635, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1282, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0933, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1635, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1616, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1153, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0666, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0303, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0656, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1384, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1740, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0681, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0868, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1469, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0877, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2132, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0358, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1099, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3879, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1996, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0363, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0627, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0528, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1093, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0842, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1392, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1892, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1517, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0706, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0981, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0877, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1035, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0695, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2446, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0758, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0816, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0974, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1025, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0592, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1310, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1229, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0339, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0580, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0749, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0485, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1140, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0896, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0691, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0199, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0302, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0944, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0409, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0153, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1418, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1531, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0786, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0806, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0159, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1163, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0914, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1855, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1532, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0720, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0793, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2706, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0918, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2227, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1966, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0298, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0163, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1315, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0785, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0867, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0488, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0370, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0324, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1283, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0940, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0985, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1908, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0469, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0497, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2318, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1478, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0675, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0404, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1396, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0353, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0813, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0171, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0710, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0574, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1702, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0637, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1769, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0244, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0177, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0568, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0291, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0411, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0315, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0372, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1218, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0245, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0293, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0626, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0642, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0607, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0520, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0930, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0603, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0724, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0262, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1661, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0291, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0313, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0895, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0707, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0206, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0963, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0580, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0098, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0242, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1055, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2146, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0117, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0963, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0469, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0049, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0676, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0221, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0984, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0989, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0097, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0162, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0906, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0190, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0173, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0229, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0707, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0912, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1005, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0457, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0169, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0090, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0201, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0431, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0286, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0266, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0145, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0190, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0461, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0223, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0343, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0087, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0083, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0081, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0230, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0967, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1162, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0381, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0031, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0694, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0152, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0286, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1295, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0818, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0346, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0214, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0374, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0388, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1053, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0327, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0058, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2687, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0195, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0168, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0347, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0241, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0366, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1205, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0369, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1375, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0670, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0505, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0069, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0472, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0071, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0620, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0234, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1589, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0582, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0122, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0194, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0786, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1739, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0535, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0444, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0934, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0275, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0638, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0716, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0947, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0198, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0228, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0522, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1216, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0107, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0838, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0481, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0577, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0683, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0843, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0150, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0926, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1180, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0998, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0206, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0113, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0228, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0939, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0193, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0281, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1123, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1317, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1207, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0674, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0131, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0333, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0601, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0179, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0114, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0135, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0090, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0446, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0861, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0172, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0300, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0128, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0390, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0258, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0311, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0126, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0509, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0735, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0068, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0265, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0141, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0583, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0073, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0224, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0534, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0061, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0445, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0228, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0118, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0898, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0185, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0093, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0230, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0131, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0118, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0034, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0042, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0176, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0836, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0421, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0140, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0232, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0271, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0383, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0878, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0338, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0249, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0140, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0107, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0128, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0149, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0185, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0089, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0087, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0098, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0146, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0070, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0295, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0127, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0195, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0103, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0344, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0136, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0054, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0260, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0226, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0269, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0395, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0452, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0342, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0410, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0496, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0958, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0165, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0500, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0323, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0077, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0255, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0337, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0519, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0046, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0114, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0438, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0057, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0087, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0058, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0903, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0069, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0038, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0038, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0098, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0755, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0075, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0114, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0039, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0048, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0051, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0405, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0028, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0141, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0382, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0339, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0270, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0035, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0134, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1505, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0029, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0057, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0087, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0040, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0166, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0071, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0170, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0171, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0204, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0812, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0173, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0140, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0181, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0036, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0078, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0040, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0061, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0159, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0034, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0085, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0066, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0485, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0043, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0798, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0136, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0028, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0176, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0063, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0006, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0042, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0079, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0082, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0165, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0292, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0039, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0179, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0062, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0062, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0166, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0195, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0289, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0287, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1434, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0266, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0042, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0143, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0275, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0485, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0035, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0126, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0926, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0065, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0090, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0260, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0003, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0048, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0004, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0148, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0047, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0092, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0056, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0143, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0164, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0126, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0128, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0263, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0600, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0098, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0005, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0032, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0111, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0069, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0159, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0031, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0215, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0061, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0044, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0421, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0054, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0074, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0269, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0411, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0146, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0045, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0057, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0179, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0125, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0298, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0132, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0200, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0050, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0058, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0043, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0032, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0029, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0182, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0118, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0081, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0966, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0054, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0107, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0036, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0065, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0006, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0029, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0145, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0303, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0117, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0037, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0074, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0025, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0075, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0036, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0142, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0065, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0575, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0058, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0218, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0052, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0083, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0003, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0134, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0057, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0096, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0007, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0089, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0025, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0496, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0144, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0100, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0032, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0040, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0111, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0046, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0078, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0055, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0062, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0039, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0002, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0029, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0063, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0143, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0007, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0036, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0450, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0752, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0148, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0510, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0118, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0046, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0105, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0077, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0007, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0005, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0054, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0041, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0108, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0040, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0053, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0037, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0040, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0032, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0094, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0034, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0028, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0004, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0104, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0057, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0059, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0037, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0036, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0050, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0079, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0006, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0088, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0112, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0042, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0581, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0033, device='mps:0', grad_fn=<NllLossBackward0>)

# %%
# %% Inspect predictions for first batch
import pandas as pd
inputs, labels = next(iter(test_loader))
inputs = inputs.to(device)
labels = labels.numpy()
outputs = model(inputs).max(1).indices.detach().cpu().numpy()
comparison = pd.DataFrame()
print("Batch accuracy: ", (labels==outputs).sum()/len(labels))
comparison["labels"] = labels

comparison["outputs"] = outputs
comparison
# Out:
# Batch accuracy:  0.78125
#     labels  outputs
# 0        1        1
# 1        0        1
# 2        1        1
# 3        1        1
# 4        0        0
# 5        1        1
# 6        3        1
# 7        2        2
# 8        1        1
# 9        3        3
# 10       0        1
# 11       0        1
# 12       2        2
# 13       0        1
# 14       1        1
# 15       2        2
# 16       3        3
# 17       3        3
# 18       3        3
# 19       2        2
# 20       2        2
# 21       3        3
# 22       0        1
# 23       2        2
# 24       2        2
# 25       2        2
# 26       0        2
# 27       3        3
# 28       1        1
# 29       0        0
# 30       3        3
# 31       2        2

# %%
def new_layer(layer, g):
    """Clone a layer and pass its parameters through the function g."""
    layer = copy.deepcopy(layer)
    try: layer.weight = torch.nn.Parameter(g(layer.weight))
    except AttributeError: pass
    try: layer.bias = torch.nn.Parameter(g(layer.bias))
    except AttributeError: pass
    return layer

def dense_to_conv(layers):
    """ Converts a dense layer to a conv layer """
    newlayers = []
    for i,layer in enumerate(layers):
        if isinstance(layer, nn.Linear):
            newlayer = None
            if i == 0:
                m, n = 512, layer.weight.shape[0]
                newlayer = nn.Conv2d(m,n,7)
                newlayer.weight = nn.Parameter(layer.weight.reshape(n,m,7,7))
            else:
                m,n = layer.weight.shape[1],layer.weight.shape[0]
                newlayer = nn.Conv2d(m,n,1)
                newlayer.weight = nn.Parameter(layer.weight.reshape(n,m,1,1))
            newlayer.bias = nn.Parameter(layer.bias)
            newlayers += [newlayer]
        else:
            newlayers += [layer]
    return newlayers

def get_linear_layer_indices(model):
    offset = len(model.vgg16._modules['features']) + 1
    indices = []
    for i, layer in enumerate(model.vgg16._modules['classifier']):
        if isinstance(layer, nn.Linear):
            indices.append(i)
    indices = [offset + val for val in indices]
    return indices

# %%
def apply_lrp_on_vgg16(model, image):
    image = torch.unsqueeze(image, 0)
    # >>> Step 1: Extract layers
    layers = list(model.vgg16._modules['features']) \
                + [model.vgg16._modules['avgpool']] \
                + dense_to_conv(list(model.vgg16._modules['classifier']))
    linear_layer_indices = get_linear_layer_indices(model)
    # >>> Step 2: Propagate image through layers and store activations
    n_layers = len(layers)
    activations = [image] + [None] * n_layers # list of activations

    for layer in range(n_layers):
        if layer in linear_layer_indices:
            if layer == 32:
                activations[layer] = activations[layer].reshape((1, 512, 7, 7))
        activation = layers[layer].forward(activations[layer])
        if isinstance(layers[layer], torch.nn.modules.pooling.AdaptiveAvgPool2d):
            activation = torch.flatten(activation, start_dim=1)
        activations[layer+1] = activation

    # >>> Step 3: Replace last layer with one-hot-encoding
    output_activation = activations[-1].detach().cpu().numpy()
    max_activation = output_activation.max()
    one_hot_output = [val if val == max_activation else 0
                        for val in output_activation[0]]

    activations[-1] = torch.FloatTensor([one_hot_output]).to(device)

    # >>> Step 4: Backpropagate relevance scores
    relevances = [None] * n_layers + [activations[-1]]
    # Iterate over the layers in reverse order
    for layer in range(0, n_layers)[::-1]:
        current = layers[layer]
        # Treat max pooling layers as avg pooling
        if isinstance(current, torch.nn.MaxPool2d):
            layers[layer] = torch.nn.AvgPool2d(2)
            current = layers[layer]
        if isinstance(current, torch.nn.Conv2d) or \
           isinstance(current, torch.nn.AvgPool2d) or\
           isinstance(current, torch.nn.Linear):
            activations[layer] = activations[layer].data.requires_grad_(True)

            # Apply variants of LRP depending on the depth
            # see: https://link.springer.com/chapter/10.1007%2F978-3-030-28954-6_10
            # Lower layers, LRP-gamma >> Favor positive contributions (activations)
            if layer <= 16:       rho = lambda p: p + 0.25*p.clamp(min=0); incr = lambda z: z+1e-9
            # Middle layers, LRP-epsilon >> Remove some noise / Only most salient factors survive
            if 17 <= layer <= 30: rho = lambda p: p;                       incr = lambda z: z+1e-9+0.25*((z**2).mean()**.5).data
            # Upper Layers, LRP-0 >> Basic rule
            if layer >= 31:       rho = lambda p: p;                       incr = lambda z: z+1e-9

            # Transform weights of layer and execute forward pass
            z = incr(new_layer(layers[layer],rho).forward(activations[layer]))
            # Element-wise division between relevance of the next layer and z
            s = (relevances[layer+1]/z).data
            # Calculate the gradient and multiply it by the activation
            (z * s).sum().backward();
            c = activations[layer].grad
            # Assign new relevance values
            relevances[layer] = (activations[layer]*c).data
        else:
            relevances[layer] = relevances[layer+1]

    # >>> Potential Step 5: Apply different propagation rule for pixels
    return relevances[0]

# %%
# Calculate relevances for first image in this test batch
image_id = 0
image_relevances = apply_lrp_on_vgg16(model, inputs[image_id])
image_relevances = image_relevances.permute(0,2,3,1).detach().cpu().numpy()[0]
image_relevances = np.interp(image_relevances, (image_relevances.min(),
                                                image_relevances.max()),
                                                (0, 1))
# Show relevances
truth_label = list(test_dataset.class_to_idx.keys())[
             list(test_dataset.class_to_idx.values())
            .index(labels[image_id])]

pred_label = list(test_dataset.class_to_idx.keys())[
             list(test_dataset.class_to_idx.values())
            .index(outputs[image_id])]


#print("Groundtruth for this image: ", pred_label)

# Plot images next to each other
fig, axs = plt.subplots(1,2, constrained_layout=True)


axs[0].imshow(inputs[image_id].permute(1,2,0).detach().cpu().numpy())
axs[0].axis('off')
axs[0].set_xlabel(f"Groundtruth: {truth_label}")
axs[0].set_title('Input')

fig.gca().set_yticklabels([])
fig.gca().set_xticklabels([])
fig.gca().set_xticks([])
fig.gca().set_yticks([])

axs[1].imshow(image_relevances[:,:,0], cmap="seismic")
#axs[1].axis('off')
axs[1].set_xlabel(f"Prediction: {pred_label}")
axs[1].set_title('Relevance of input features with LRP')



plt.show()
